# %%
import time
import random

from lineplot import LinePlot

plot = LinePlot()

for i in range(100):
    time.sleep(0.25)
    plot.add(x=1/(i+1), y=random.random())
# Out:
# <script src="https://cdn.jsdelivr.net/npm/chart.js"></script>
# <div style="width: 50%">
#   <canvas id="chart5635404"></canvas>
# </div>
